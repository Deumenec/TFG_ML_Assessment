# %%
#Disorder comparison plots. In this plot, the disorder associated with a given structure is compared with the pLDDT of an alphafold model, showing how there is no good correlation
import json
import matplotlib.pyplot as plt

with open('longchain_data.json', 'r') as f:
    data1 = json.load(f)  # This loads the file content into a Python dictionary
    
len_aminoacids = {
    "A": 5,  # ALA
    "R": 11, # ARG
    "N": 8,  # ASN
    "D": 8,  # ASP
    "C": 6,  # CYS
    "Q": 9,  # GLN
    "E": 9,  # GLU
    "G": 4,  # GLY
    "H": 10, # HIS
    "I": 8,  # ILE
    "L": 8,  # LEU
    "K": 9,  # LYS
    "M": 8,  # MET
    "F": 11, # PHE
    "P": 7,  # PRO
    "S": 6,  # SER
    "T": 7,  # THR
    "W": 14, # TRP
    "Y": 12, # TYR
    "V": 7   # VAL
}

# %%
print("Keys from the dictionary are: "+ str(data1.keys()))
plddt = data1["atom_plddts"]
analized_chain= []
for i in range(len(data1)):
    analized_chain.append(plddt[i])
plt.plot(plddt[16770:16790], color='#daa520')
print(plddt[16781])
#16670 is the atom number associated with the residue indicated in the thesis
#Where one can clearly see clashes while the pLDDT yields 54.81.
# Out:
# Keys from the dictionary are: dict_keys(['atom_chain_ids', 'atom_plddts', 'contact_probs', 'pae', 'token_chain_ids', 'token_res_ids'])
# 47.23

# %%
print(id_num[2000])
# Out:
# 285
